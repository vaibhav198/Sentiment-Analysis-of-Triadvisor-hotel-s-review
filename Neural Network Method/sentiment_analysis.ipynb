# %% [markdown]
# # Sentiment Analysis using Bidirectional LSTM

# %% [markdown]
# <b><i>Importing python libraries</i></b>

# %%
import numpy as np
from sen_utils import *
np.random.seed(0)
from keras.models import Model
from keras.layers import Dense, Input, Dropout, LSTM, Activation, Bidirectional
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.initializers import glorot_uniform
from keras.optimizers import Adam
np.random.seed(1)
import re
import string
from unicodedata import normalize
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# <b><i>Reading dataset in train and test varibles</i></b>

# %%
colnames=['Reviews','Labels'] 
df= pd.read_csv('data/Dataset_.csv', names=colnames, header=None)
df = df.sample(frac=1).reset_index(drop=True)
print(df.head())
# Out:
#                                  Reviews  Labels
# 0                                awesome       5
# 1        couples are mostly welcome here       5
# 2  Thanking Mr Abhilek For best service.       5
# 3                             True treat       5
# 4                         Cheap and best       4

# %%
df = df.values
X = df[:,0]
Y = df[:,1]

# %%
X
# Out:
# array(['awesome', 'couples are mostly welcome here',
#        'Thanking Mr Abhilek For best service.', 'True treat',
#        'Cheap and best', 'Not just a Retreat, a true Treat.',
#        'Not a good reflection of the positive reviews', 'Good Stay',
#        'Dont visit the resort  by seeing the  pics uploaded in their website',
#        'Official visit 03days',
#        'i booked the hotel for one night and was my worst experience of life',
#        'What a breath of fresh air!', 'awesome grand',
#        'Amazing city Varanasi.', 'some problem',
#        'excellent hotel to stay', 'Very professional',
#        'Wonderful Retreat', 'awesome grand',
#        'Not a good reflection of the positive reviews', '89 reviews',
#        'Unworthy of Stay. Period.', 'Pleasant stay in beautiful Hotel',
#        'Stunning property ', 'Not a place for family ', 'Awesome hotel',
#        'Memorable Wedding Reception', 'NGO',
#        'Good Hotel adjacent to Railway station',
#        'Beautiful hotel located near Taj.', 'Poor Food', 'Worst Stay',
#        'Excellent stay in Varanasi at Hotel Buddha',
#        'Not value for money', 'Tajness',
#        'Comfortable Rooms and Excellent Service', 'Happy moments',
#        'Not a Peasant stay', 'Fortune Hotel-Guest Review',
#        'Excellent stay', 'Best property in Gwalior ',
#        'Birthday Celebration Dinner', 'Good holidays', 'Nice stay',
#        'Yes. Iwill suggest people to stay in this hotel with family. The location is very good and transport is easily achievab',
#        'ONE OF THE BEST PLACES TO STAY IN LUCKNOW.',
#        'OMG! What a delightful paradise ~ GREAT staff! AWESOME food!',
#        'Good hotel', 'Not value for money', 'Safe and comfy stay',
#        'Excellent stay ', 'Clean and friendly',
#        'A new type of heaven being offered', 'Terrible experience',
#        'Best wedding place for Wedding in the City',
#        'name say it all Zero complain very clean and friendly staff',
#        'Surprisingly Stylish & Spacious Interiors near town ',
#        'Really a great hotel', 'Decent room but poor amenities',
#        'An excellent choice to stay in all respects', 'Lovely Hotel',
#        'Good place to chill after roaming the busy streets',
#        'GREAT PLACE TO STAY WHEN IN TIRUPATI', 'Holidays', 'Good service',
#        'Excellent Hotel', 'Expensive for what you get', 'Good service',
#        'Memorable Wedding Reception', 'Beautiful hotel and good stay',
#        'ROOM CONDITION', 'Not a good reflection of the positive reviews',
#        'Modern Hotel in India', 'Friendly staff great service great food',
#        'Good service', 'Official visit 03days', 'Wonderful stay',
#        'An Amazing place to stay - Business or Leisure - Solo or Family - Great Experience',
#        'Go see it for yourself!', 'Tajness',
#        'Bella vista- lovely experience', 'Wonderful stay with my wife',
#        'Very good surprise in Agra',
#        'Had good time peaceful reception for meeting. Room size is good with all amenities.good place for relax and enjoy',
#        'Excellent Hospitality and Great Memories',
#        'Nice hotel with ridiculously priced wine', 'Memories of the Taj',
#        'Birthday Celebration Dinner', 'Holidays',
#        'Great rooftop restaurant and friendly staff',
#        'Amazing hospitality',
#        'Awesome Place to spend quality time with Friends and family !!',
#        'Good Stay', 'Excellent hotel', 'Happy grand stay',
#        'Fabulously done up rooms',
#        'Good price cosy restaurant and good location', 'Good',
#        'Had good time peaceful reception for meeting. Room size is good with all amenities.good place for relax and enjoy .',
#        'Great location with calm serene resort...Best package for couple and small family...',
#        'Very professional',
#        'Awesome Place to spend quality time with Friends and family !!',
#        'Clean and friendly', 'Always a pleasure to visit Lebua',
#        'Good place to chill after roaming the busy streets',
#        'Good stay in front of the beach',
#        'couples are mostly welcome here', 'awesome ...',
#        'Bell Vista Club', 'The Villa Retreat Experience',
#        'Clean and calm with AMAZING views!',
#        'Is it a Hotel Then what is hut', 'An excellent place',
#        'Nice stay', 'Most beautiful property in the heart of Lucknow.',
#        'Good, But Overpriced', 'average', 'Not value for money',
#        'Worst Resort Ever',
#        'Would definitely recommend to stay in awesome Grands Coimbatore',
#        'Beautiful traditional hotel very helpful staff  good location',
#        'i booked the hotel for one night and was my worst experience of life',
#        'Excellent stay at awesome Resort',
#        'Prime location with excellent tours!',
#        'Nice hotel with ridiculously priced wine',
#        'Authentic Awadhi Food', 'Perfect Airport Hotel',
#        'Best hotel in best location ',
#        'Surprisingly Stylish & Spacious Interiors near town ',
#        'Is it a Hotel.? Then what is hut', 'Good enough', 'Awesome hotel',
#        'Good Hotel adjacent to Railway station',
#        'Thanking Mr Abhilek For best service.',
#        'Unprofessional and Worst Customer Service ', 'Poor Food',
#        'My stay at the Taj Resorts', 'Beautiful hotel located near Taj.',
#        'Good service', 'Nice Vacation', 'A trip full of surprises',
#        'Luxurious rooms and palatial interiors', 'Amazing stay in India',
#        'Quaint stay at Santana', 'One night',
#        'Disappointed that pool wasn’t available.',
#        'Most beautiful property in the heart of Lucknow.',
#        'Excellent service and Housekeeping', 'Good service',
#        'Super Amazing Property with Super Friendly Staff',
#        'Excellent hotel',
#        'name say it all, Zero complain very clean and friendly staff',
#        'Nice stay near to Taj Mahal', 'Superb ',
#        'Very nice stay, I recommend', 'Good holidays',
#        'Not a good reflection of the positive reviews',
#        'Good intermittent layover airport hotel',
#        '#799 of 968 Hotels in Bengaluru',
#        'OMG! What a delightful paradise GREAT staff AWESOME food',
#        'Deo Bagh is an oasis of calm in a busy area and we feel like royalty here',
#        'Fabulous', 'Business', 'A warm welcome',
#        'A trip full of surprises', 'Beautiful property',
#        'Stunning Hotel, Helpful staff and Boutique Property',
#        'The Villa Retreat Experience', 'Worst Resort ever............',
#        'Holidays', 'The most dirty hotel that i stayed',
#        'Very good hotel', 'Stay at radisson',
#        'Beautiful hotel and good stay',
#        'Dont visit the resort  by seeing the  pics uploaded in their website',
#        'Expensive for what you get', 'Perfect Airport Hotel',
#        'Was pleasantly surprised',
#        'Nice hotel with ridiculously priced wine',
#        'Unprofessional and Worst Customer Service',
#        'Not a place for family ',
#        'Beautiful traditional hotel, very helpful staff, good location',
#        'Always a pleasure to visit Lebua', 'Hospitable Heritage Hotel',
#        'Good services hotels', 'Shahpura House',
#        'Nice characterful hotel', 'Close to the Taj',
#        'The most dirty hotel that i stayed',
#        'Good intermittent layover airport hotel',
#        'Not a place for family', 'Comfort stay',
#        'My stay at the Taj Resorts',
#        'Deo Bagh is an oasis of calm in a busy area and we feel like royalty here!',
#        'Good stay with great service', 'Good', 'awesome',
#        'Not a Peasant stay', 'Bell Vista Club',
#        'Excellent hotel, location and price', 'Bell Vista Club',
#        'Fabulous week at Om Sai Beach Huts',
#        'Amazing Hotel with very courteous staff and cleanliness',
#        'Good, But Overpriced', 'Worst', 'Not a very good place to stay',
#        'Finest Experience in CME', 'Not a Peasant stay', 'Nice Vacation',
#        'Friendly staff, great service, great food', 'Worst Resort ever',
#        'Fantastic, Excellent, Refreshing Stay.', 'Beautiful property',
#        'Cheap and best', 'Awesome place', 'The terrace grill bar',
#        'Bella vista- lovely experience', 'Not a very good place to stay',
#        'Best hotel in best location ', 'Excellent Good~ ',
#        'The Best Resort for a wonderful family stay in Mahabaleshwar!!',
#        'Good stay with great service', 'Wonderful stay with my wife',
#        'Not value for money', 'Worst Stay', '217 reviews',
#        'Wonderful Retreat', 'Good service',
#        'Best wedding place for Wedding in the City', "B'day with family",
#        'Mr RAJIV Khosla', 'Rude and unprofessional staff',
#        'Was pleasantly surprised', 'Excellent service and Housekeeping',
#        'Clean and calm with AMAZING views!', 'Best Retreat',
#        'Pool and brekkie 5 star', 'Happy moments',
#        'The Best Resort for a wonderful family stay in Mahabaleshwar',
#        'Not bad', 'Pleasant stay', 'Best hotel',
#        'Pool and brekkie 5 star', 'Beautiful property',
#        'Beautiful property', 'Good down-town hotel',
#        'Amazing city Varanasi.',
#        'Disappointed that pool wasn’t available.', 'Not value for money',
#        'Best Retreat', 'some problem', 'Very good hotel', 'Worst Stay',
#        'Views are to die for',
#        'A decent place to stay with exceptional hospitality',
#        'Finest Experience in CME', 'Decent room but poor amenities',
#        'Fantastic Hospitality Great Team !!', 'ROOM CONDITION',
#        'Wonderful team at Sarovar', 'Poor Food', 'Not value for money',
#        'Excellent Hotel', 'Nice place for family stay', 'Good enough',
#        'Not a good reflection of the positive reviews',
#        'Unworthy of Stay. Period.', 'Worst Resort ever',
#        'Would definitely recommend to stay in awesome Grands Coimbatore',
#        'Great location with calm serene resort...Best package for couple and small family',
#        'Great hotel with central location', 'NGO', 'Worst',
#        'A warm welcome', 'Couples Friendly', 'Terrible experience',
#        'Amazing stay in India',
#        'Nice hotel with ridiculously priced wine',
#        'Beautiful restaurant , friendly and delicious food. Reasonable price',
#        'Not a very good place to stay',
#        'ONE OF THE BEST PLACES TO STAY IN LUCKNOW.', 'Mr RAJIV Khosla',
#        'Lovely Hotel', 'Poor Food', 'awesome', 'Modern Hotel in India',
#        'Excellent stay in Varanasi at Hotel Buddha', 'Excellent, Good~ ',
#        'Super Amazing Property with Super Friendly Staff',
#        'A highly recommended hotel for convenience and service',
#        'Go see it for yourself!', 'Fabulous week at Om Sai Beach Huts',
#        'i booked the hotel for one night and was my worst experience of life.',
#        'Authentic Awadhi Food', 'Nice characterful hotel',
#        'Farewell party ', 'Excellent hotel', 'Not value for money',
#        'Nice place for family stay', 'Hospitable Heritage Hotel',
#        'Excellent customer service', 'Excellent stay',
#        'The most dirty hotel that i stayed', 'A great weekend of peace',
#        'Amazing Mohini!', 'best service and warm welcome',
#        'Great hotel with central location',
#        'good hotel at very nice location', 'Couples Friendly',
#        'Close to the Taj', "Can't get it Right! Overrated property!",
#        'A great weekend of peace', 'Poor Food', 'Pleasant stay',
#        'Not a good reflection of the positive reviews',
#        'GREAT PLACE TO STAY WHEN IN TIRUPATI', 'Our home away from home.',
#        'Hospitable Heritage Hotel', 'Stay at radisson', 'Tatiana Khosla',
#        'Not bad', 'Business', 'Home away from Home', 'Very professional',
#        'Luxurious rooms, and palatial interiors',
#        'What a breath of fresh air!',
#        'Not a good reflection of the positive reviews',
#        'Dont visit the resort  by seeing the  pics uploaded in their website',
#        'Lovely heritage hotel  in a tranquil garden',
#        'Fortune Hotel-Guest Review', 'Best hotel', 'Awesome place',
#        'Not a very good place to stay', 'Close to the Taj',
#        'Disappointed that pool wasn’t available',
#        'Decent room but poor amenities', 'Good hotel in budget',
#        'Nice stay near to Taj Mahal', 'Comfort stay', 'average',
#        'Excellent customer service',
#        'Good place for business or family stay', "B'day with family",
#        'Good price, cosy restaurant and good location',
#        'Amazing Hotel with very courteous staff and cleanliness',
#        'colorfull Holi',
#        'A decent place to stay with exceptional hospitality',
#        'Good stay in front of the beach', 'Memories of the Taj',
#        'Rude and unprofessional staff.', 'Good down-town hotel',
#        'Happy grand stay', 'Trip to bangalore', 'Farewell party ',
#        'Rude and unprofessional staff.', 'Excellent stay ',
#        'An assault on the senses in Varanasi',
#        'Great location with calm serene resort Best package for couple and small family',
#        'An excellent choice to stay in all respects',
#        'Good stay in front of the beach',
#        'Beautiful restaurant friendly and delicious food Reasonable price',
#        'Stunning Hotel Helpful staff and Boutique Property',
#        'Unworthy of Stay Period', 'Fabulously done up rooms',
#        'Very professional', 'average', 'Shahpura House',
#        'Surprisingly good', 'Good service',
#        'Not a very good place to stay', 'True treat',
#        'Decent room but poor amenities',
#        'Always a pleasure to visit Lebua', 'The terrace grill bar',
#        'Great rooftop restaurant and friendly staff', 'Stunning property',
#        'Amazing Mohini!', 'Not just a Retreat a true Treat', 'Poor Food',
#        'Yes. Iwill suggest people to stay in this hotel, with family. The location is very good and transport is easily achievab',
#        'A new type of heaven being offered...',
#        'Pleasant stay in beautiful Hotel', 'Introduction to India',
#        'colorfull Holi', 'Very nice stay I recommend',
#        'Views are to die for',
#        'A highly recommended hotel for convenience and service',
#        'Holidays', 'Fantastic',
#        'At the heart of the old city and right on the Ganga', 'Superb ',
#        'Wonderful stay', 'Amazing hospitality',
#        'Excellent Hospitality and Great Memories', 'Enjoyable short stay',
#        'Great place to stay in centre of Varanasi ', 'Trip to bangalore',
#        'Comfortable and clean with good service!',
#        'Is it a Hotel.? Then what is hut..???',
#        'Lovely heritage hotel  in a tranquil garden', 'Excellent Hotel',
#        'Home away from Home', 'Wonderful team at Sarovar',
#        'Expensive for what you get', 'VELLORE', 'Worst',
#        'Fantastic Hospitality, Great Team !!',
#        'Great place to stay in centre of Varanasi ',
#        'Excellent stay at awesome Resort',
#        'Excellent hotel location and price',
#        'Decent room but poor amenities', 'Tatiana Khosla',
#        'Terrible experience', 'excellent hotel to stay', 'VELLORE',
#        'Safe and comfy stay .'], dtype=object)

# %% [markdown]
# <b><i>Function to clean our dataset</i></b>

# %%
def clean_lines(lines):
    cleaned = list()
    # prepare regex for char filtering
    re_print = re.compile('[^%s]' % re.escape(string.printable))
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)

    for line in lines:
        # normalize unicode characters
        line = normalize('NFD', line).encode('ascii', 'ignore')
        line = line.decode('UTF-8')
        # tokenize on white space
        line = line.split()
        # convert to lowercase
        line = [word.lower() for word in line]
        # remove punctuation from each token
        line = [word.translate(table) for word in line]
        # remove non-printable chars form each token
        line = [re_print.sub('', w) for w in line]
        # remove tokens with numbers in them
        line = [word for word in line if word.isalpha()]
        # store as string
        cleaned.append(' '.join(line))
    return np.array(cleaned)

# %%
X = clean_lines(X)
X
# Out:
# array(['awesome', 'couples are mostly welcome here',
#        'thanking mr abhilek for best service', 'true treat',
#        'cheap and best', 'not just a retreat a true treat',
#        'not a good reflection of the positive reviews', 'good stay',
#        'dont visit the resort by seeing the pics uploaded in their website',
#        'official visit',
#        'i booked the hotel for one night and was my worst experience of life',
#        'what a breath of fresh air', 'awesome grand',
#        'amazing city varanasi', 'some problem', 'excellent hotel to stay',
#        'very professional', 'wonderful retreat', 'awesome grand',
#        'not a good reflection of the positive reviews', 'reviews',
#        'unworthy of stay period', 'pleasant stay in beautiful hotel',
#        'stunning property', 'not a place for family', 'awesome hotel',
#        'memorable wedding reception', 'ngo',
#        'good hotel adjacent to railway station',
#        'beautiful hotel located near taj', 'poor food', 'worst stay',
#        'excellent stay in varanasi at hotel buddha',
#        'not value for money', 'tajness',
#        'comfortable rooms and excellent service', 'happy moments',
#        'not a peasant stay', 'fortune hotelguest review',
#        'excellent stay', 'best property in gwalior',
#        'birthday celebration dinner', 'good holidays', 'nice stay',
#        'yes iwill suggest people to stay in this hotel with family the location is very good and transport is easily achievab',
#        'one of the best places to stay in lucknow',
#        'omg what a delightful paradise great staff awesome food',
#        'good hotel', 'not value for money', 'safe and comfy stay',
#        'excellent stay', 'clean and friendly',
#        'a new type of heaven being offered', 'terrible experience',
#        'best wedding place for wedding in the city',
#        'name say it all zero complain very clean and friendly staff',
#        'surprisingly stylish spacious interiors near town',
#        'really a great hotel', 'decent room but poor amenities',
#        'an excellent choice to stay in all respects', 'lovely hotel',
#        'good place to chill after roaming the busy streets',
#        'great place to stay when in tirupati', 'holidays', 'good service',
#        'excellent hotel', 'expensive for what you get', 'good service',
#        'memorable wedding reception', 'beautiful hotel and good stay',
#        'room condition', 'not a good reflection of the positive reviews',
#        'modern hotel in india', 'friendly staff great service great food',
#        'good service', 'official visit', 'wonderful stay',
#        'an amazing place to stay business or leisure solo or family great experience',
#        'go see it for yourself', 'tajness',
#        'bella vista lovely experience', 'wonderful stay with my wife',
#        'very good surprise in agra',
#        'had good time peaceful reception for meeting room size is good with all amenitiesgood place for relax and enjoy',
#        'excellent hospitality and great memories',
#        'nice hotel with ridiculously priced wine', 'memories of the taj',
#        'birthday celebration dinner', 'holidays',
#        'great rooftop restaurant and friendly staff',
#        'amazing hospitality',
#        'awesome place to spend quality time with friends and family',
#        'good stay', 'excellent hotel', 'happy grand stay',
#        'fabulously done up rooms',
#        'good price cosy restaurant and good location', 'good',
#        'had good time peaceful reception for meeting room size is good with all amenitiesgood place for relax and enjoy',
#        'great location with calm serene resortbest package for couple and small family',
#        'very professional',
#        'awesome place to spend quality time with friends and family',
#        'clean and friendly', 'always a pleasure to visit lebua',
#        'good place to chill after roaming the busy streets',
#        'good stay in front of the beach',
#        'couples are mostly welcome here', 'awesome', 'bell vista club',
#        'the villa retreat experience',
#        'clean and calm with amazing views',
#        'is it a hotel then what is hut', 'an excellent place',
#        'nice stay', 'most beautiful property in the heart of lucknow',
#        'good but overpriced', 'average', 'not value for money',
#        'worst resort ever',
#        'would definitely recommend to stay in awesome grands coimbatore',
#        'beautiful traditional hotel very helpful staff good location',
#        'i booked the hotel for one night and was my worst experience of life',
#        'excellent stay at awesome resort',
#        'prime location with excellent tours',
#        'nice hotel with ridiculously priced wine',
#        'authentic awadhi food', 'perfect airport hotel',
#        'best hotel in best location',
#        'surprisingly stylish spacious interiors near town',
#        'is it a hotel then what is hut', 'good enough', 'awesome hotel',
#        'good hotel adjacent to railway station',
#        'thanking mr abhilek for best service',
#        'unprofessional and worst customer service', 'poor food',
#        'my stay at the taj resorts', 'beautiful hotel located near taj',
#        'good service', 'nice vacation', 'a trip full of surprises',
#        'luxurious rooms and palatial interiors', 'amazing stay in india',
#        'quaint stay at santana', 'one night',
#        'disappointed that pool wasnt available',
#        'most beautiful property in the heart of lucknow',
#        'excellent service and housekeeping', 'good service',
#        'super amazing property with super friendly staff',
#        'excellent hotel',
#        'name say it all zero complain very clean and friendly staff',
#        'nice stay near to taj mahal', 'superb',
#        'very nice stay i recommend', 'good holidays',
#        'not a good reflection of the positive reviews',
#        'good intermittent layover airport hotel',
#        'of hotels in bengaluru',
#        'omg what a delightful paradise great staff awesome food',
#        'deo bagh is an oasis of calm in a busy area and we feel like royalty here',
#        'fabulous', 'business', 'a warm welcome',
#        'a trip full of surprises', 'beautiful property',
#        'stunning hotel helpful staff and boutique property',
#        'the villa retreat experience', 'worst resort ever', 'holidays',
#        'the most dirty hotel that i stayed', 'very good hotel',
#        'stay at radisson', 'beautiful hotel and good stay',
#        'dont visit the resort by seeing the pics uploaded in their website',
#        'expensive for what you get', 'perfect airport hotel',
#        'was pleasantly surprised',
#        'nice hotel with ridiculously priced wine',
#        'unprofessional and worst customer service',
#        'not a place for family',
#        'beautiful traditional hotel very helpful staff good location',
#        'always a pleasure to visit lebua', 'hospitable heritage hotel',
#        'good services hotels', 'shahpura house',
#        'nice characterful hotel', 'close to the taj',
#        'the most dirty hotel that i stayed',
#        'good intermittent layover airport hotel',
#        'not a place for family', 'comfort stay',
#        'my stay at the taj resorts',
#        'deo bagh is an oasis of calm in a busy area and we feel like royalty here',
#        'good stay with great service', 'good', 'awesome',
#        'not a peasant stay', 'bell vista club',
#        'excellent hotel location and price', 'bell vista club',
#        'fabulous week at om sai beach huts',
#        'amazing hotel with very courteous staff and cleanliness',
#        'good but overpriced', 'worst', 'not a very good place to stay',
#        'finest experience in cme', 'not a peasant stay', 'nice vacation',
#        'friendly staff great service great food', 'worst resort ever',
#        'fantastic excellent refreshing stay', 'beautiful property',
#        'cheap and best', 'awesome place', 'the terrace grill bar',
#        'bella vista lovely experience', 'not a very good place to stay',
#        'best hotel in best location', 'excellent good',
#        'the best resort for a wonderful family stay in mahabaleshwar',
#        'good stay with great service', 'wonderful stay with my wife',
#        'not value for money', 'worst stay', 'reviews',
#        'wonderful retreat', 'good service',
#        'best wedding place for wedding in the city', 'bday with family',
#        'mr rajiv khosla', 'rude and unprofessional staff',
#        'was pleasantly surprised', 'excellent service and housekeeping',
#        'clean and calm with amazing views', 'best retreat',
#        'pool and brekkie star', 'happy moments',
#        'the best resort for a wonderful family stay in mahabaleshwar',
#        'not bad', 'pleasant stay', 'best hotel', 'pool and brekkie star',
#        'beautiful property', 'beautiful property', 'good downtown hotel',
#        'amazing city varanasi', 'disappointed that pool wasnt available',
#        'not value for money', 'best retreat', 'some problem',
#        'very good hotel', 'worst stay', 'views are to die for',
#        'a decent place to stay with exceptional hospitality',
#        'finest experience in cme', 'decent room but poor amenities',
#        'fantastic hospitality great team', 'room condition',
#        'wonderful team at sarovar', 'poor food', 'not value for money',
#        'excellent hotel', 'nice place for family stay', 'good enough',
#        'not a good reflection of the positive reviews',
#        'unworthy of stay period', 'worst resort ever',
#        'would definitely recommend to stay in awesome grands coimbatore',
#        'great location with calm serene resortbest package for couple and small family',
#        'great hotel with central location', 'ngo', 'worst',
#        'a warm welcome', 'couples friendly', 'terrible experience',
#        'amazing stay in india',
#        'nice hotel with ridiculously priced wine',
#        'beautiful restaurant friendly and delicious food reasonable price',
#        'not a very good place to stay',
#        'one of the best places to stay in lucknow', 'mr rajiv khosla',
#        'lovely hotel', 'poor food', 'awesome', 'modern hotel in india',
#        'excellent stay in varanasi at hotel buddha', 'excellent good',
#        'super amazing property with super friendly staff',
#        'a highly recommended hotel for convenience and service',
#        'go see it for yourself', 'fabulous week at om sai beach huts',
#        'i booked the hotel for one night and was my worst experience of life',
#        'authentic awadhi food', 'nice characterful hotel',
#        'farewell party', 'excellent hotel', 'not value for money',
#        'nice place for family stay', 'hospitable heritage hotel',
#        'excellent customer service', 'excellent stay',
#        'the most dirty hotel that i stayed', 'a great weekend of peace',
#        'amazing mohini', 'best service and warm welcome',
#        'great hotel with central location',
#        'good hotel at very nice location', 'couples friendly',
#        'close to the taj', 'cant get it right overrated property',
#        'a great weekend of peace', 'poor food', 'pleasant stay',
#        'not a good reflection of the positive reviews',
#        'great place to stay when in tirupati', 'our home away from home',
#        'hospitable heritage hotel', 'stay at radisson', 'tatiana khosla',
#        'not bad', 'business', 'home away from home', 'very professional',
#        'luxurious rooms and palatial interiors',
#        'what a breath of fresh air',
#        'not a good reflection of the positive reviews',
#        'dont visit the resort by seeing the pics uploaded in their website',
#        'lovely heritage hotel in a tranquil garden',
#        'fortune hotelguest review', 'best hotel', 'awesome place',
#        'not a very good place to stay', 'close to the taj',
#        'disappointed that pool wasnt available',
#        'decent room but poor amenities', 'good hotel in budget',
#        'nice stay near to taj mahal', 'comfort stay', 'average',
#        'excellent customer service',
#        'good place for business or family stay', 'bday with family',
#        'good price cosy restaurant and good location',
#        'amazing hotel with very courteous staff and cleanliness',
#        'colorfull holi',
#        'a decent place to stay with exceptional hospitality',
#        'good stay in front of the beach', 'memories of the taj',
#        'rude and unprofessional staff', 'good downtown hotel',
#        'happy grand stay', 'trip to bangalore', 'farewell party',
#        'rude and unprofessional staff', 'excellent stay',
#        'an assault on the senses in varanasi',
#        'great location with calm serene resort best package for couple and small family',
#        'an excellent choice to stay in all respects',
#        'good stay in front of the beach',
#        'beautiful restaurant friendly and delicious food reasonable price',
#        'stunning hotel helpful staff and boutique property',
#        'unworthy of stay period', 'fabulously done up rooms',
#        'very professional', 'average', 'shahpura house',
#        'surprisingly good', 'good service',
#        'not a very good place to stay', 'true treat',
#        'decent room but poor amenities',
#        'always a pleasure to visit lebua', 'the terrace grill bar',
#        'great rooftop restaurant and friendly staff', 'stunning property',
#        'amazing mohini', 'not just a retreat a true treat', 'poor food',
#        'yes iwill suggest people to stay in this hotel with family the location is very good and transport is easily achievab',
#        'a new type of heaven being offered',
#        'pleasant stay in beautiful hotel', 'introduction to india',
#        'colorfull holi', 'very nice stay i recommend',
#        'views are to die for',
#        'a highly recommended hotel for convenience and service',
#        'holidays', 'fantastic',
#        'at the heart of the old city and right on the ganga', 'superb',
#        'wonderful stay', 'amazing hospitality',
#        'excellent hospitality and great memories', 'enjoyable short stay',
#        'great place to stay in centre of varanasi', 'trip to bangalore',
#        'comfortable and clean with good service',
#        'is it a hotel then what is hut',
#        'lovely heritage hotel in a tranquil garden', 'excellent hotel',
#        'home away from home', 'wonderful team at sarovar',
#        'expensive for what you get', 'vellore', 'worst',
#        'fantastic hospitality great team',
#        'great place to stay in centre of varanasi',
#        'excellent stay at awesome resort',
#        'excellent hotel location and price',
#        'decent room but poor amenities', 'tatiana khosla',
#        'terrible experience', 'excellent hotel to stay', 'vellore',
#        'safe and comfy stay'], dtype='<U117')

# %% [markdown]
# <b><i>Maximum length of the longest sentence in the dataset</i></b>

# %%
maxLen = len(max(X, key=len).split())

# %%
m = len(df)
train = int(0.8*m)
dev = int(0.1*m)
test = int(0.1*m)

# %%
df[:dev,1].shape
# Out:
# (41,)

# %% [markdown]
# <b><i>Splitting data into train, dev and test</i></b>

# %%
X_train = np.array(list(X[:train]))
Y_train = np.array(list(Y[:train]))
X_dev = np.array(list(X[train:train+dev]))
Y_dev = np.array(list(Y[train:train+dev]))
X_test = np.array(list(X[train+dev:train+dev+test]))
Y_test = np.array(list(Y[train+dev:train+dev+test]))

# %%
Y_dev
# Out:
# array([2, 3, 3, 2, 5, 5, 3, 3, 5, 4, 3, 5, 5, 5, 4, 4, 5, 1, 4, 4, 2, 5,
#        1, 5, 5, 4, 5, 4, 5, 5, 1, 5, 4, 3, 4, 5, 4, 0, 5, 2, 4])

# %%
print(X_train.shape)
print(X_dev.shape)
print(X_test.shape)
# Out:
# (332,)
# (41,)
# (41,)

# %% [markdown]
# <b><i>Converting the train, dev and test label to their one hot vector form matrix</i></b>

# %%
Y_train_oh = convert_to_one_hot(Y_train, C = 6)
Y_dev_oh = convert_to_one_hot(Y_dev, C = 6)
Y_test_oh = convert_to_one_hot(Y_test, C = 6)
print(Y_train_oh.shape)
# Out:
# (332, 6)

# %% [markdown]
# <b><i>Function to read and store the glove embedding matrix</i></b>

# %%
def read_glove_vecs(glove_file):
    with open(glove_file, 'r', encoding="utf8") as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            line = line.strip().split()
            curr_word = line[0]
            words.add(curr_word)
            word_to_vec_map[curr_word] = np.array(line[1:], dtype=np.float64)
        
        i = 1
        words_to_index = {}
        index_to_words = {}
        for w in sorted(words):
            words_to_index[w] = i
            index_to_words[i] = w
            i = i + 1
    return words_to_index, index_to_words, word_to_vec_map

# %% [markdown]
# <b><i>Reading the glove embedding matrix</i></b>

# %%
word_to_index, index_to_word, word_to_vec_map = read_glove_vecs('data/glove.6B.50d.txt')

# %% [markdown]
# <b><i>Function convert every sentence to its corresponding indices vector using word_to_index dictionary; it also pads zero if incase the sentence vector is less than the max length of the sentence </i></b>

# %%
def sentences_to_indices(X, word_to_index, max_len):
 
    m = X.shape[0]
    print(m)
    X_indices = np.zeros((m, max_len))
    for i in range(m):                               
        
        sentence_words = X[i].split()
        j = 0
        
        for w in sentence_words:
            if w in word_to_index.keys(): 
                X_indices[i, j] = word_to_index[w]
            else:
                X_indices[i, j] = word_to_index['awesome']
            j = j + 1
    
    return X_indices

# %%
X_train_indices = sentences_to_indices(X_train, word_to_index, maxLen)
X_dev_indices = sentences_to_indices(X_dev, word_to_index, maxLen)
X_train_indices.shape
# Out:
# 332
# 41
# (332, 21)

# %% [markdown]
# <b><i>Function builds the <u>Embedding()</u> layer in Keras. After this layer is built, we can pass the output of <u>sentences_to_indices()</u> to it as an input, and the Embedding() layer will return the word embeddings for that sentence.</i></b>

# %%
def pretrained_embedding_layer(word_to_vec_map, word_to_index):

    vocab_len = len(word_to_index) + 1                  
    emb_dim = word_to_vec_map["cucumber"].shape[0]
    
    emb_matrix = np.zeros((vocab_len, emb_dim))
    
    for word, index in word_to_index.items():
        emb_matrix[index, :] = word_to_vec_map[word]

    embedding_layer = Embedding(vocab_len, emb_dim, trainable = False)

    embedding_layer.build((None,))
    embedding_layer.set_weights([emb_matrix])
    
    return embedding_layer

# %% [markdown]
# <b><i>Model Function</i></b>

# %%
def classify(input_shape, word_to_vec_map, word_to_index):

    sentence_indices = Input(shape = input_shape, dtype = 'int32')
    
    embedding_layer = pretrained_embedding_layer(word_to_vec_map, word_to_index)
    
    # Propagate sentence_indices through your embedding layer, you get back the embeddings
    embeddings = embedding_layer(sentence_indices)
    
    # Propagate the embeddings through an LSTM layer with 128-dimensional hidden state; the returned output should be a batch of sequences.
    X = Bidirectional(LSTM(128, return_sequences=True))(embeddings)
    X = Dropout(0.5)(X)
    
    # Propagate X trough another LSTM layer with 128-dimensional hidden state; the returned output should be a single hidden state, not a batch of sequences.
    X = Bidirectional(LSTM(128, return_sequences=False))(X)
    
    # Add dropout with a probability of 0.5
    X = Dropout(0.5)(X)
    # Propagate X through a Dense layer with softmax activation to get back a batch of 5-dimensional vectors.
    X = Dense(6)(X)
    # Add a softmax activation
    X = Activation('softmax')(X)
    
    model = Model(inputs = sentence_indices, outputs = X)
    
    return model

# %% [markdown]
# <b><i>Calling the Model Function</i></b>

# %%
model = classify((maxLen,), word_to_vec_map, word_to_index)

# %%
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %% [markdown]
# <b><i>Compiling the model</i></b>

# %%
opt = Adam(lr=0.01, beta_1=0.9, beta_2=0.999, decay=0.01)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <b><i>Fitting our training data to the compiled model</i></b>

# %%
model.fit(X_train_indices, Y_train_oh, epochs = 100, batch_size = 20, validation_data=(X_dev_indices, Y_dev_oh), callbacks=[checkpoint])
# Out:
# Train on 332 samples, validate on 41 samples
# Epoch 1/100
# 332/332 [==============================] - 4s 13ms/step - loss: 1.3328 - acc: 0.5482 - val_loss: 1.3821 - val_acc: 0.4634
#
# Epoch 00001: val_loss improved from inf to 1.38213, saving model to model.h5
# Epoch 2/100
# 332/332 [==============================] - 2s 5ms/step - loss: 1.0061 - acc: 0.6145 - val_loss: 1.2802 - val_acc: 0.5366
#
# Epoch 00002: val_loss improved from 1.38213 to 1.28023, saving model to model.h5
# Epoch 3/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.7933 - acc: 0.6747 - val_loss: 1.1666 - val_acc: 0.6098
#
# Epoch 00003: val_loss improved from 1.28023 to 1.16659, saving model to model.h5
# Epoch 4/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.6411 - acc: 0.7620 - val_loss: 1.2020 - val_acc: 0.5122
#
# Epoch 00004: val_loss did not improve from 1.16659
# Epoch 5/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.5297 - acc: 0.7952 - val_loss: 0.9358 - val_acc: 0.6585
#
# Epoch 00005: val_loss improved from 1.16659 to 0.93584, saving model to model.h5
# Epoch 6/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.4824 - acc: 0.8163 - val_loss: 0.8931 - val_acc: 0.6341
#
# Epoch 00006: val_loss improved from 0.93584 to 0.89309, saving model to model.h5
# Epoch 7/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.3641 - acc: 0.8494 - val_loss: 0.6466 - val_acc: 0.7073
#
# Epoch 00007: val_loss improved from 0.89309 to 0.64665, saving model to model.h5
# Epoch 8/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.3346 - acc: 0.8675 - val_loss: 0.5839 - val_acc: 0.8537
#
# Epoch 00008: val_loss improved from 0.64665 to 0.58391, saving model to model.h5
# Epoch 9/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.2366 - acc: 0.8916 - val_loss: 0.6332 - val_acc: 0.7317
#
# Epoch 00009: val_loss did not improve from 0.58391
# Epoch 10/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.2035 - acc: 0.9157 - val_loss: 0.5975 - val_acc: 0.8049
#
# Epoch 00010: val_loss did not improve from 0.58391
# Epoch 11/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.2441 - acc: 0.8765 - val_loss: 0.6473 - val_acc: 0.7317
#
# Epoch 00011: val_loss did not improve from 0.58391
# Epoch 12/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.2495 - acc: 0.9006 - val_loss: 0.5460 - val_acc: 0.7805
#
# Epoch 00012: val_loss improved from 0.58391 to 0.54600, saving model to model.h5
# Epoch 13/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.2421 - acc: 0.8916 - val_loss: 0.5511 - val_acc: 0.7805
#
# Epoch 00013: val_loss did not improve from 0.54600
# Epoch 14/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1994 - acc: 0.9096 - val_loss: 0.3921 - val_acc: 0.8537
#
# Epoch 00014: val_loss improved from 0.54600 to 0.39213, saving model to model.h5
# Epoch 15/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1423 - acc: 0.9488 - val_loss: 0.4321 - val_acc: 0.8537
#
# Epoch 00015: val_loss did not improve from 0.39213
# Epoch 16/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1518 - acc: 0.9398 - val_loss: 0.4357 - val_acc: 0.8537
#
# Epoch 00016: val_loss did not improve from 0.39213
# Epoch 17/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1450 - acc: 0.9247 - val_loss: 0.3339 - val_acc: 0.9268
#
# Epoch 00017: val_loss improved from 0.39213 to 0.33389, saving model to model.h5
# Epoch 18/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1277 - acc: 0.9367 - val_loss: 0.3924 - val_acc: 0.8780oss: 0.1462 - acc: 0.
#
# Epoch 00018: val_loss did not improve from 0.33389
# Epoch 19/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1354 - acc: 0.9277 - val_loss: 0.3674 - val_acc: 0.8780
#
# Epoch 00019: val_loss did not improve from 0.33389
# Epoch 20/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1105 - acc: 0.9488 - val_loss: 0.3671 - val_acc: 0.8780
#
# Epoch 00020: val_loss did not improve from 0.33389
# Epoch 21/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1089 - acc: 0.9518 - val_loss: 0.3635 - val_acc: 0.8780
#
# Epoch 00021: val_loss did not improve from 0.33389
# Epoch 22/100
# 332/332 [==============================] - 1s 4ms/step - loss: 0.0966 - acc: 0.9488 - val_loss: 0.3663 - val_acc: 0.8780
#
# Epoch 00022: val_loss did not improve from 0.33389
# Epoch 23/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1156 - acc: 0.9367 - val_loss: 0.3463 - val_acc: 0.9024
#
# Epoch 00023: val_loss did not improve from 0.33389
# Epoch 24/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1146 - acc: 0.9398 - val_loss: 0.3550 - val_acc: 0.8780
#
# Epoch 00024: val_loss did not improve from 0.33389
# Epoch 25/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1105 - acc: 0.9367 - val_loss: 0.3468 - val_acc: 0.8780
#
# Epoch 00025: val_loss did not improve from 0.33389
# Epoch 26/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1142 - acc: 0.9337 - val_loss: 0.3981 - val_acc: 0.8537
#
# Epoch 00026: val_loss did not improve from 0.33389
# Epoch 27/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1166 - acc: 0.9367 - val_loss: 0.4348 - val_acc: 0.8537
#
# Epoch 00027: val_loss did not improve from 0.33389
# Epoch 28/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1047 - acc: 0.9488 - val_loss: 0.3514 - val_acc: 0.8780
#
# Epoch 00028: val_loss did not improve from 0.33389
# Epoch 29/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1111 - acc: 0.9458 - val_loss: 0.3480 - val_acc: 0.8780
#
# Epoch 00029: val_loss did not improve from 0.33389
# Epoch 30/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0885 - acc: 0.9458 - val_loss: 0.3755 - val_acc: 0.8537
#
# Epoch 00030: val_loss did not improve from 0.33389
# Epoch 31/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1070 - acc: 0.9458 - val_loss: 0.3829 - val_acc: 0.8537
#
# Epoch 00031: val_loss did not improve from 0.33389
# Epoch 32/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1187 - acc: 0.9428 - val_loss: 0.4079 - val_acc: 0.9024
#
# Epoch 00032: val_loss did not improve from 0.33389
# Epoch 33/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0952 - acc: 0.9518 - val_loss: 0.3660 - val_acc: 0.8780
#
# Epoch 00033: val_loss did not improve from 0.33389
# Epoch 34/100
# 332/332 [==============================] - 1s 5ms/step - loss: 0.0954 - acc: 0.9578 - val_loss: 0.3666 - val_acc: 0.9268
#
# Epoch 00034: val_loss did not improve from 0.33389
# Epoch 35/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1045 - acc: 0.9307 - val_loss: 0.4248 - val_acc: 0.8537
#
# Epoch 00035: val_loss did not improve from 0.33389
# Epoch 36/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0980 - acc: 0.9548 - val_loss: 0.3703 - val_acc: 0.8537
#
# Epoch 00036: val_loss did not improve from 0.33389
# Epoch 37/100
# 332/332 [==============================] - 1s 4ms/step - loss: 0.0905 - acc: 0.9608 - val_loss: 0.3994 - val_acc: 0.8537
#
# Epoch 00037: val_loss did not improve from 0.33389
# Epoch 38/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1029 - acc: 0.9488 - val_loss: 0.4136 - val_acc: 0.8537
#
# Epoch 00038: val_loss did not improve from 0.33389
# Epoch 39/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0926 - acc: 0.9518 - val_loss: 0.4323 - val_acc: 0.8537
#
# Epoch 00039: val_loss did not improve from 0.33389
# Epoch 40/100
# 332/332 [==============================] - 1s 5ms/step - loss: 0.0944 - acc: 0.9398 - val_loss: 0.4391 - val_acc: 0.8537
#
# Epoch 00040: val_loss did not improve from 0.33389
# Epoch 41/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0848 - acc: 0.9608 - val_loss: 0.4557 - val_acc: 0.8537
#
# Epoch 00041: val_loss did not improve from 0.33389
# Epoch 42/100
# 332/332 [==============================] - 1s 5ms/step - loss: 0.1007 - acc: 0.9458 - val_loss: 0.4189 - val_acc: 0.8537
#
# Epoch 00042: val_loss did not improve from 0.33389
# Epoch 43/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1033 - acc: 0.9488 - val_loss: 0.3547 - val_acc: 0.9024
#
# Epoch 00043: val_loss did not improve from 0.33389
# Epoch 44/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0826 - acc: 0.9578 - val_loss: 0.4046 - val_acc: 0.8537
#
# Epoch 00044: val_loss did not improve from 0.33389
# Epoch 45/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0951 - acc: 0.9548 - val_loss: 0.3786 - val_acc: 0.8537
#
# Epoch 00045: val_loss did not improve from 0.33389
# Epoch 46/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0881 - acc: 0.9488 - val_loss: 0.3938 - val_acc: 0.9024
#
# Epoch 00046: val_loss did not improve from 0.33389
# Epoch 47/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0960 - acc: 0.9458 - val_loss: 0.3735 - val_acc: 0.8537
#
# Epoch 00047: val_loss did not improve from 0.33389
# Epoch 48/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0809 - acc: 0.9518 - val_loss: 0.3613 - val_acc: 0.8537
#
# Epoch 00048: val_loss did not improve from 0.33389
# Epoch 49/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.1046 - acc: 0.9337 - val_loss: 0.3932 - val_acc: 0.8537
#
# Epoch 00049: val_loss did not improve from 0.33389
# Epoch 50/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0874 - acc: 0.9578 - val_loss: 0.4041 - val_acc: 0.9024
#
# Epoch 00050: val_loss did not improve from 0.33389
# Epoch 51/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0893 - acc: 0.9428 - val_loss: 0.4113 - val_acc: 0.8537
#
# Epoch 00051: val_loss did not improve from 0.33389
# Epoch 52/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0930 - acc: 0.9398 - val_loss: 0.4219 - val_acc: 0.8537
#
# Epoch 00052: val_loss did not improve from 0.33389
# Epoch 53/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0913 - acc: 0.9578 - val_loss: 0.3730 - val_acc: 0.9024
#
# Epoch 00053: val_loss did not improve from 0.33389
# Epoch 54/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0875 - acc: 0.9518 - val_loss: 0.3702 - val_acc: 0.9024
#
# Epoch 00054: val_loss did not improve from 0.33389
# Epoch 55/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0905 - acc: 0.9548 - val_loss: 0.3773 - val_acc: 0.9024
#
# Epoch 00055: val_loss did not improve from 0.33389
# Epoch 56/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0888 - acc: 0.9428 - val_loss: 0.4099 - val_acc: 0.9024
#
# Epoch 00056: val_loss did not improve from 0.33389
# Epoch 57/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0787 - acc: 0.9488 - val_loss: 0.4028 - val_acc: 0.9024
#
# Epoch 00057: val_loss did not improve from 0.33389
# Epoch 58/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0895 - acc: 0.9458 - val_loss: 0.4371 - val_acc: 0.9024
#
# Epoch 00058: val_loss did not improve from 0.33389
# Epoch 59/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0855 - acc: 0.9548 - val_loss: 0.4886 - val_acc: 0.9024
#
# Epoch 00059: val_loss did not improve from 0.33389
# Epoch 60/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0841 - acc: 0.9428 - val_loss: 0.4652 - val_acc: 0.8537
#
# Epoch 00060: val_loss did not improve from 0.33389
# Epoch 61/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0920 - acc: 0.9458 - val_loss: 0.4439 - val_acc: 0.9024
#
# Epoch 00061: val_loss did not improve from 0.33389
# Epoch 62/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0927 - acc: 0.9428 - val_loss: 0.4038 - val_acc: 0.9024
#
# Epoch 00062: val_loss did not improve from 0.33389
# Epoch 63/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0834 - acc: 0.9488 - val_loss: 0.4258 - val_acc: 0.9024
#
# Epoch 00063: val_loss did not improve from 0.33389
# Epoch 64/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0758 - acc: 0.9578 - val_loss: 0.4450 - val_acc: 0.8537
#
# Epoch 00064: val_loss did not improve from 0.33389
# Epoch 65/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0859 - acc: 0.9548 - val_loss: 0.4392 - val_acc: 0.9024
#
# Epoch 00065: val_loss did not improve from 0.33389
# Epoch 66/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0753 - acc: 0.9548 - val_loss: 0.4139 - val_acc: 0.9024
#
# Epoch 00066: val_loss did not improve from 0.33389
# Epoch 67/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0931 - acc: 0.9488 - val_loss: 0.4394 - val_acc: 0.9024
#
# Epoch 00067: val_loss did not improve from 0.33389
# Epoch 68/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0989 - acc: 0.9367 - val_loss: 0.4514 - val_acc: 0.9024
#
# Epoch 00068: val_loss did not improve from 0.33389
# Epoch 69/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0757 - acc: 0.9518 - val_loss: 0.4192 - val_acc: 0.9024
#
# Epoch 00069: val_loss did not improve from 0.33389
# Epoch 70/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0871 - acc: 0.9518 - val_loss: 0.4257 - val_acc: 0.9024
#
# Epoch 00070: val_loss did not improve from 0.33389
# Epoch 71/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0927 - acc: 0.9548 - val_loss: 0.4453 - val_acc: 0.9024
#
# Epoch 00071: val_loss did not improve from 0.33389
# Epoch 72/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0841 - acc: 0.9428 - val_loss: 0.4731 - val_acc: 0.9024
#
# Epoch 00072: val_loss did not improve from 0.33389
# Epoch 73/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0816 - acc: 0.9578 - val_loss: 0.4880 - val_acc: 0.9024
#
# Epoch 00073: val_loss did not improve from 0.33389
# Epoch 74/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0902 - acc: 0.9458 - val_loss: 0.4250 - val_acc: 0.8537
#
# Epoch 00074: val_loss did not improve from 0.33389
# Epoch 75/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0857 - acc: 0.9639 - val_loss: 0.4774 - val_acc: 0.8537
#
# Epoch 00075: val_loss did not improve from 0.33389
# Epoch 76/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0924 - acc: 0.9488 - val_loss: 0.4280 - val_acc: 0.8537
#
# Epoch 00076: val_loss did not improve from 0.33389
# Epoch 77/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0784 - acc: 0.9608 - val_loss: 0.4112 - val_acc: 0.8537
#
# Epoch 00077: val_loss did not improve from 0.33389
# Epoch 78/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0945 - acc: 0.9337 - val_loss: 0.4583 - val_acc: 0.8537
#
# Epoch 00078: val_loss did not improve from 0.33389
# Epoch 79/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0860 - acc: 0.9458 - val_loss: 0.4414 - val_acc: 0.8537
#
# Epoch 00079: val_loss did not improve from 0.33389
# Epoch 80/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0823 - acc: 0.9518 - val_loss: 0.4371 - val_acc: 0.8537
#
# Epoch 00080: val_loss did not improve from 0.33389
# Epoch 81/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0878 - acc: 0.9458 - val_loss: 0.4392 - val_acc: 0.9024
#
# Epoch 00081: val_loss did not improve from 0.33389
# Epoch 82/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0878 - acc: 0.9458 - val_loss: 0.4642 - val_acc: 0.8537
#
# Epoch 00082: val_loss did not improve from 0.33389
# Epoch 83/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0813 - acc: 0.9518 - val_loss: 0.4718 - val_acc: 0.9024
#
# Epoch 00083: val_loss did not improve from 0.33389
# Epoch 84/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0781 - acc: 0.9518 - val_loss: 0.4637 - val_acc: 0.9024
#
# Epoch 00084: val_loss did not improve from 0.33389
# Epoch 85/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0817 - acc: 0.9518 - val_loss: 0.4556 - val_acc: 0.9024
#
# Epoch 00085: val_loss did not improve from 0.33389
# Epoch 86/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0749 - acc: 0.9669 - val_loss: 0.4599 - val_acc: 0.9024
#
# Epoch 00086: val_loss did not improve from 0.33389
# Epoch 87/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0845 - acc: 0.9518 - val_loss: 0.4632 - val_acc: 0.9024
#
# Epoch 00087: val_loss did not improve from 0.33389
# Epoch 88/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0944 - acc: 0.9518 - val_loss: 0.4392 - val_acc: 0.9024
#
# Epoch 00088: val_loss did not improve from 0.33389
# Epoch 89/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0903 - acc: 0.9428 - val_loss: 0.4207 - val_acc: 0.9024
#
# Epoch 00089: val_loss did not improve from 0.33389
# Epoch 90/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0803 - acc: 0.9458 - val_loss: 0.4341 - val_acc: 0.9024
#
# Epoch 00090: val_loss did not improve from 0.33389
# Epoch 91/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0787 - acc: 0.9518 - val_loss: 0.4251 - val_acc: 0.9024
#
# Epoch 00091: val_loss did not improve from 0.33389
# Epoch 92/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0861 - acc: 0.9488 - val_loss: 0.3988 - val_acc: 0.9024
#
# Epoch 00092: val_loss did not improve from 0.33389
# Epoch 93/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0868 - acc: 0.9488 - val_loss: 0.4026 - val_acc: 0.9024
#
# Epoch 00093: val_loss did not improve from 0.33389
# Epoch 94/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0816 - acc: 0.9518 - val_loss: 0.4098 - val_acc: 0.9024
#
# Epoch 00094: val_loss did not improve from 0.33389
# Epoch 95/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0849 - acc: 0.9578 - val_loss: 0.4416 - val_acc: 0.9024
#
# Epoch 00095: val_loss did not improve from 0.33389
# Epoch 96/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0805 - acc: 0.9398 - val_loss: 0.4188 - val_acc: 0.9024
#
# Epoch 00096: val_loss did not improve from 0.33389
# Epoch 97/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0778 - acc: 0.9578 - val_loss: 0.4103 - val_acc: 0.8537
#
# Epoch 00097: val_loss did not improve from 0.33389
# Epoch 98/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0920 - acc: 0.9458 - val_loss: 0.4261 - val_acc: 0.9024
#
# Epoch 00098: val_loss did not improve from 0.33389
# Epoch 99/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0910 - acc: 0.9548 - val_loss: 0.4354 - val_acc: 0.9024
#
# Epoch 00099: val_loss did not improve from 0.33389
# Epoch 100/100
# 332/332 [==============================] - 2s 5ms/step - loss: 0.0818 - acc: 0.9578 - val_loss: 0.4404 - val_acc: 0.8537
#
# Epoch 00100: val_loss did not improve from 0.33389

# %% [markdown]
# <b><i>Converting our test data to testable form and evaluating our model</i></b>

# %%
X_test_indices = sentences_to_indices(X_test, word_to_index, max_len = maxLen)
loss, acc = model.evaluate(X_test_indices, Y_test_oh)
print("Test accuracy = ", acc)
# Out:
# 41
# 41/41 [==============================] - 0s 1ms/step
# Test accuracy =  0.8536585365853658
